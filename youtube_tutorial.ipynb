# %% [markdown]
# gonna follow this playlist
#
# https://www.youtube.com/watch?v=IC0_FRiX-sw&list=PL_lsbAsL_o2CTlGHgMxNrKhzP97BaG9ZN&index=1
#
# https://docs.pytorch.org/tutorials/beginner/introyt/introyt_index.html

# %% [markdown]
# lowkey wanna watch this too https://www.youtube.com/watch?v=r1bquDz5GGA
